# %%
import numpy as np
import pandas as pd

# !pip install gensim

import gensim
import os

# %% [markdown]
# ### Gensim : It is an open source library in python written by Radim Rehurek which is used in unsupervised topic modelling and natural language processing. It is designed to extract semantic topics from documents. It can handle large text collections.

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('gameofthrones') :
    f = open(os.path.join("gameofthrones" , filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent :
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145020

# %%
# story

model = gensim.models.Word2Vec(
    window = 10 ,
    min_count = 2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples = model.corpus_count , epochs = model.epochs)
# Out:
# (6569436, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8007405996322632),
#  ('targaryen', 0.7973848581314087),
#  ('queen', 0.7338639497756958),
#  ('unburnt', 0.7178228497505188),
#  ('viserys', 0.6782535314559937),
#  ('aegon', 0.6772295832633972),
#  ('myrcella', 0.661242663860321),
#  ('princess', 0.6588168144226074),
#  ('elia', 0.64946448802948),
#  ('baelor', 0.6438101530075073)]

# %%
model.wv.doesnt_match(['jon' , 'rikon' , 'arya' , 'sansa' , 'bran'])
# Out:
# 'jon'

# %%
model.wv.doesnt_match(['cersei' , 'jaime' , 'bronn' , 'tyrion'])
# Out:
# 'bronn'

# %%
model.wv['jon']
# Out:
# array([ 0.7116097 , -0.9375614 ,  0.51298404, -1.2565567 ,  0.9683454 ,
#         0.8699226 ,  0.9645897 , -0.21443957, -1.3477397 ,  0.0876247 ,
#        -2.1550715 ,  0.50896204, -1.019232  , -2.7757611 , -1.0714191 ,
#         0.6948472 ,  1.5611703 ,  3.1449208 , -1.092787  , -0.95767546,
#         1.5451903 , -2.1105301 , -0.5048738 ,  1.6068339 , -3.2617855 ,
#        -0.47375   ,  2.0324216 , -0.15731798,  0.622351  ,  0.3182171 ,
#        -1.5528163 , -1.2742944 ,  0.22048023, -0.66148794,  0.20582983,
#         0.08851325,  0.3583897 ,  1.2335849 ,  1.1026008 ,  1.9637359 ,
#        -0.16828488, -1.0725046 ,  2.6339986 ,  0.75837094,  1.4862419 ,
#        -1.2104423 , -0.8916891 ,  1.0457892 ,  0.16995174,  1.389063  ,
#         0.37307835, -0.6341659 ,  2.2201443 , -0.6737341 ,  1.5044836 ,
#         0.35122126,  0.24140964, -2.673655  ,  1.8362262 , -1.3642838 ,
#        -0.5388384 ,  1.7396765 ,  1.1219549 , -1.9101571 , -0.44120058,
#        -0.76064414,  0.08931694,  2.338105  , -1.460789  , -0.1851756 ,
#         1.6110142 , -1.8956608 , -0.18646292,  0.94278127,  0.9629869 ,
#         1.2002716 , -1.4220539 ,  2.0916371 , -0.9401985 , -0.3241377 ,
#        -1.2853338 , -1.8862331 , -1.5158759 ,  1.4073242 , -2.9070385 ,
#         1.3441395 ,  0.15948442, -1.3631976 , -0.02071253,  0.4877799 ,
#         0.5497789 ,  1.0363616 ,  1.1124909 , -0.6362175 ,  2.682144  ,
#        -1.3670499 ,  1.1386065 , -2.3217914 ,  0.28028324, -0.06706176],
#       dtype=float32)

# %%
model.wv["king"].shape
# Out:
# (100,)

# %%
model.wv.similarity("arya","sansa")
# Out:
# np.float32(0.8331424)

# %%
model.wv.similarity("tywin","sansa")
# Out:
# np.float32(0.19013919)
